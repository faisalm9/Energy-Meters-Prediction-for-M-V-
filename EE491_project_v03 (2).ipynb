# %% [markdown]
# ##*performing Long Short Term Memory(LSTM) Model to predict Energy Usage*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# import csv files from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the file 500_buildings in google drive

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/proc/500_buildings.csv')

# %%
df.head()
# Out:
#              timestamp  building_id  meter_reading  meter  month  weekday  \
# 0  2016-02-29 09:00:00         1076       148.4476      0      2        0
# 1  2016-02-29 10:00:00         1076       235.0420      0      2        0
# 2  2016-02-29 11:00:00         1076       272.1539      0      2        0
# 3  2016-02-29 12:00:00         1076       296.8952      0      2        0
# 4  2016-02-29 13:00:00         1076       346.3777      0      2        0
#
#    hour  site_id  primaryspaceusage      sqm  airTemperature
# 0     9       12                  3  17433.0            16.7
# 1    10       12                  3  17433.0            21.1
# 2    11       12                  3  17433.0            21.7
# 3    12       12                  3  17433.0            22.2
# 4    13       12                  3  17433.0            23.9

# %%
df['meter'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
# filter only the building_id number 183 and 211 and 239

df_filter = df[df['building_id'].isin([183])]

# %%
df_filter.head()
# Out:
#                   timestamp  building_id  meter_reading  meter  month  \
# 949906  2016-01-01 00:00:00          183         0.0000      0      1
# 949907  2016-01-01 01:00:00          183       157.9424      0      1
# 949908  2016-01-01 02:00:00          183       160.7869      0      1
# 949909  2016-01-01 03:00:00          183       156.2107      0      1
# 949910  2016-01-01 04:00:00          183       157.6949      0      1
#
#         weekday  hour  site_id  primaryspaceusage     sqm  airTemperature
# 949906        4     0        2                  3  7954.6             9.4
# 949907        4     1        2                  3  7954.6             8.9
# 949908        4     2        2                  3  7954.6             8.9
# 949909        4     3        2                  3  7954.6             8.3
# 949910        4     4        2                  3  7954.6             7.8

# %%
# filter only the meter type 0 and show

df_filter = df_filter[df_filter['meter'] == 0]

# %%
df_filter['meter'].unique()
# Out:
# array([0])

# %%
#  remove the columns  	month	weekday	hour		primaryspaceusage

df_filter.drop(['month', 'weekday', 'hour', 'primaryspaceusage'], axis=1, inplace=True)
# Out:
# <ipython-input-11-5a5ed4bc4687>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter.drop(['month', 'weekday', 'hour', 'primaryspaceusage'], axis=1, inplace=True)

# %%
# show the data

df_filter.head()
# Out:
#                   timestamp  building_id  meter_reading  meter  site_id  \
# 949906  2016-01-01 00:00:00          183         0.0000      0        2
# 949907  2016-01-01 01:00:00          183       157.9424      0        2
# 949908  2016-01-01 02:00:00          183       160.7869      0        2
# 949909  2016-01-01 03:00:00          183       156.2107      0        2
# 949910  2016-01-01 04:00:00          183       157.6949      0        2
#
#            sqm  airTemperature
# 949906  7954.6             9.4
# 949907  7954.6             8.9
# 949908  7954.6             8.9
# 949909  7954.6             8.3
# 949910  7954.6             7.8

# %%
# remove meter column

df_filter.drop(['meter'], axis=1, inplace=True)
# Out:
# <ipython-input-13-f0ed736e121f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter.drop(['meter'], axis=1, inplace=True)

# %%
# clean the data

df_filter.fillna(method='ffill')
df_filter.fillna(method='bfill')
df_filter.isnull().sum()
# Out:
# timestamp         0
# building_id       0
# meter_reading     0
# site_id           0
# sqm               0
# airTemperature    0
# dtype: int64

# %%
# split the data to be training < 2017-1-1 00:00:00 and testing >2017-1-1 00:00:00

# splitting the data

train = df_filter[df_filter['timestamp'] < '2017-1-1 00:00:00']
test = df_filter[df_filter['timestamp'] >= '2017-1-1 00:00:00']

# %%
pd.DataFrame(test)
# Out:
#                   timestamp  building_id  meter_reading  site_id     sqm  \
# 965235  2017-10-01 00:00:00          183       562.0127        2  7954.6
# 965236  2017-10-01 01:00:00          183       555.8283        2  7954.6
# 965237  2017-10-01 02:00:00          183       544.9443        2  7954.6
# 965238  2017-10-01 03:00:00          183       538.7603        2  7954.6
# 965239  2017-10-01 04:00:00          183       508.9529        2  7954.6
# ...                     ...          ...            ...      ...     ...
# 967429  2017-12-31 19:00:00          183         4.8237        2  7954.6
# 967430  2017-12-31 20:00:00          183       180.8234        2  7954.6
# 967431  2017-12-31 21:00:00          183       109.5826        2  7954.6
# 967432  2017-12-31 22:00:00          183       112.0563        2  7954.6
# 967433  2017-12-31 23:00:00          183       105.1299        2  7954.6
#
#         airTemperature
# 965235            19.4
# 965236            18.9
# 965237            18.9
# 965238            17.8
# 965239            17.8
# ...                ...
# 967429            -1.1
# 967430            -1.1
# 967431            -1.7
# 967432            -2.2
# 967433            -2.2
#
# [2199 rows x 6 columns]

# %%
train_datetime = train['timestamp']
test_datetime = test['timestamp']

# %%
train = train.drop(columns=['timestamp'])
test = test.drop(columns=['timestamp'])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %%
features = ['site_id', 'sqm', 'airTemperature']
target = 'meter_reading'

# %%
train_features = train_scaled[:, [0] + list(range(2, train_scaled.shape[1]))]
train_target = train_scaled[:, 1]
test_features = test_scaled[:, [0] + list(range(2, train_scaled.shape[1]))]
test_target = test_scaled[:, 1]

# %%
# LSTM model with 50 hidden units
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_features.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# using the adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# training the model
model.fit(train_features, train_target, epochs=100, batch_size=32, callbacks=[early_stopping], validation_split=0.2)

# evaluating the model
model.evaluate(test_features, test_target)

# making predictions
predictions_scaled = model.predict(test_features)
# Out:
# Epoch 1/100
# 384/384 [==============================] - 11s 11ms/step - loss: 5.7606e-04 - val_loss: 1.3179e-04
# Epoch 2/100
# 384/384 [==============================] - 4s 12ms/step - loss: 5.2140e-04 - val_loss: 1.2691e-04
# Epoch 3/100
# 384/384 [==============================] - 3s 8ms/step - loss: 5.1662e-04 - val_loss: 1.3833e-04
# Epoch 4/100
# 384/384 [==============================] - 3s 8ms/step - loss: 5.1055e-04 - val_loss: 1.3704e-04
# Epoch 5/100
# 384/384 [==============================] - 3s 8ms/step - loss: 5.1053e-04 - val_loss: 1.4411e-04
# Epoch 6/100
# 384/384 [==============================] - 4s 11ms/step - loss: 5.1146e-04 - val_loss: 1.3614e-04
# Epoch 7/100
# 384/384 [==============================] - 3s 9ms/step - loss: 5.0714e-04 - val_loss: 1.3609e-04
# 69/69 [==============================] - 0s 3ms/step - loss: 4.5696e-04
# 69/69 [==============================] - 1s 3ms/step

# %%
predictions = predictions_scaled.ravel().reshape(-1, 1)



# Plotting the results with a wider plot and improved layout
plt.figure(figsize=(15, 6))
plt.plot(test_datetime, test_target, color='red', label='Real Meter Reading')
plt.plot(test_datetime, predictions, color='blue', label='Predicted Meter Reading')
plt.xlabel('Time')
plt.ylabel('Meter Reading')
plt.ylim([0, 0.3])
plt.legend()
plt.tight_layout()
plt.show()
